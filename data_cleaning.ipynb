# %% [markdown]
# <a href="https://colab.research.google.com/github/chaimajaballah0/tweets_sentiment_analysis/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DataFrame
import pandas as pd

# Utility
import re
import string
import numpy as np
import os
import time
import pickle
import itertools


# NLTK NLP kit(only so much for our needs)
import nltk 
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from  nltk.stem import SnowballStemmer
from sklearn.model_selection import train_test_split
# Out:
# [nltk_data] Downloading package stopwords to /home/chaima/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/chaima/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# DATASET
DATASET_COLUMNS = ["target", "ids", "date", "flag", "user", "text"]
DATASET_ENCODING = "ISO-8859-1"

# %%
#load the dataset in a dataframe
data = pd.read_csv("raw_data/training_1600000_processed_noemoticon.csv", encoding =DATASET_ENCODING , names=DATASET_COLUMNS)

# %%
data.head()
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
#label the target into negative, neutral and positive with a mapping function.
decode_map = {0: "NEGATIVE", 2: "NEUTRAL", 4: "POSITIVE"}
def decode_sentiment(label):
    return decode_map[int(label)]
    
data.target = data.target.apply(lambda x: decode_sentiment(x))

# %%
data.to_pickle('data.pkl')

# %%
data.head(5)
# Out:
#      target         ids                          date      flag  \
# 0  NEGATIVE  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1  NEGATIVE  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2  NEGATIVE  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3  NEGATIVE  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4  NEGATIVE  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
data_cleaned = data

# %%
# Apply first round of data cleaning 
# Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

round1 = lambda x: clean_text(x)
# Let's take a look at the updated text
data_cleaned.text= data_cleaned.text.apply(round1)
data_cleaned
# Out:
#            target         ids                          date      flag  \
# 0        NEGATIVE  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1        NEGATIVE  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2        NEGATIVE  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3        NEGATIVE  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4        NEGATIVE  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...           ...         ...                           ...       ...
# 1599995  POSITIVE  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996  POSITIVE  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997  POSITIVE  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998  POSITIVE  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999  POSITIVE  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %%
# Apply a second round of cleaning
# Get rid of some additional punctuation and non-sensical text that was missed the first time around.

def clean_text_additional(text,stem=False):
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_additional(x)
# Let's take a look at the updated text
data_cleaned.text = data_cleaned.text.apply(round2)
data_cleaned
# Out:
#            target         ids                          date      flag  \
# 0        NEGATIVE  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1        NEGATIVE  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2        NEGATIVE  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3        NEGATIVE  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4        NEGATIVE  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...           ...         ...                           ...       ...
# 1599995  POSITIVE  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996  POSITIVE  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997  POSITIVE  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998  POSITIVE  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999  POSITIVE  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %%
print(stopwords.words('english'))
emoticons = [":)", ':-)', ': )', ':D', '=)', ':(', ':-(', ': (']
stpwrd = nltk.corpus.stopwords.words('english')
stpwrd.extend(emoticons)
stpwrd
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
# Remove emojis from data
data_cleaned = data_cleaned.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))

# %%
data_cleaned
# Out:
#            target         ids                          date      flag  \
# 0        NEGATIVE  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1        NEGATIVE  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2        NEGATIVE  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3        NEGATIVE  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4        NEGATIVE  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...           ...         ...                           ...       ...
# 1599995  POSITIVE  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996  POSITIVE  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997  POSITIVE  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998  POSITIVE  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999  POSITIVE  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %%
# Remove urls
def remove_username_link_nums(text):
    text = re.sub('www\.[^\s]+', '', text)
    text = re.sub('@[^\s]+', '', text)
    text = re.sub('http[^\s]+', '', text)
    text = re.sub(r'\d+', '', text)
    return text

data_cleaned.text = data_cleaned.text.apply(remove_username_link_nums)

# %%
data_cleaned
# Out:
#            target         ids                          date      flag  \
# 0        NEGATIVE  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1        NEGATIVE  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2        NEGATIVE  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3        NEGATIVE  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4        NEGATIVE  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...           ...         ...                           ...       ...
# 1599995  POSITIVE  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996  POSITIVE  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997  POSITIVE  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998  POSITIVE  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999  POSITIVE  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %%
# Remove stopwords and lemmatize the text
lem = WordNetLemmatizer()
def remove_stopwords(text): 
  tokens = []
  for token in text.split():
    if token not in stpwrd:
      tokens.append(lem.lemmatize(token, "v"))
 
  return  " ".join(tokens)

data_cleaned.text = data_cleaned.text.apply(lambda x: remove_stopwords(x))

# %%
#Stemmize the text
stemmer = SnowballStemmer("english")
def stemming_on_text(text):
    tokens = []
    for token in text.split():
        if stem:
            tokens.append(stemmer.stem(token))
        else:
            tokens.append(token)
 
    return  " ".join(tokens)

data_cleaned.text = data_cleaned.text.apply(lambda x: stemming_on_text(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb Cell 17 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> #Stemmize the text
# ----> <a href='vscode-notebook-cell:/home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> st = nltk.PorterStemmer()
#       <a href='vscode-notebook-cell:/home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> def stemming_on_text(text):
#       <a href='vscode-notebook-cell:/home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a>     tokens = []
#
# NameError: name 'nltk' is not defined

# %%
data_cleaned.columns
# Out:
# Index(['target', 'ids', 'date', 'flag', 'user', 'text'], dtype='object')

# %%
data_cleaned = data_cleaned.drop(['ids', 'date', 'flag', 'user'], axis = 1)

# %%
# Let's pickle it for later use
data_cleaned.to_pickle("data_cleaned.pkl")

# %%
#Split the data into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(data_cleaned.text, data_cleaned.target,
                                                    test_size = 0.3, random_state = 0)
print(f'Data Split done.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb Cell 20 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> X_train, X_test, y_train, y_test = train_test_split(processedtext, sentiment,
#       <a href='vscode-notebook-cell:/home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a>                                                     test_size = 0.05, random_state = 0)
#       <a href='vscode-notebook-cell:/home/chaima/Desktop/sentiment_analysis/data_cleaning.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> print(f'Data Split done.')
#
# NameError: name 'train_test_split' is not defined

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(.text)

vocab_size = len(tokenizer.word_index) + 1
print("Total words", vocab_size)
